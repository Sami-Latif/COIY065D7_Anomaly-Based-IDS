# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/sami/Documents/CS Postgrad/Preply/COIY065D7_Anomaly-Based-IDS/Data/entire_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46776700 entries, 0 to 46776699
# Data columns (total 40 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Header_Length    float64
#  1   Protocol Type    int64
#  2   Time_To_Live     float64
#  3   Rate             float64
#  4   fin_flag_number  float64
#  5   syn_flag_number  float64
#  6   rst_flag_number  float64
#  7   psh_flag_number  float64
#  8   ack_flag_number  float64
#  9   ece_flag_number  float64
#  10  cwr_flag_number  float64
#  11  ack_count        float64
#  12  syn_count        float64
#  13  fin_count        float64
#  14  rst_count        float64
#  15  HTTP             float64
#  16  HTTPS            float64
#  17  DNS              float64
#  18  Telnet           float64
#  19  SMTP             float64
#  20  SSH              float64
#  21  IRC              float64
#  22  TCP              float64
#  23  UDP              float64
#  24  DHCP             float64
# ...

# %%
print(df.shape)
# Out:
# (21694579, 40)

# %%
df["label"].value_counts()
# Out:
# label
# DDoS-UDP_Flood             2042002
# DDoS-ICMP_Flood            1978358
# DDoS-SYN_Flood             1835456
# DoS-UDP_Flood              1771430
# DDoS-PSHACK_FLOOD          1705094
# DDoS-TCP_Flood             1620909
# DDoS-RSTFINFLOOD           1302706
# DDoS-SynonymousIP_Flood    1214691
# DoS-SYN_Flood              1185281
# DoS-TCP_Flood              1164079
# Benign_Final               1093940
# Mirai-greeth_flood          936306
# Mirai-udpplain              799346
# Mirai-greip_flood           724410
# DDoS-ICMP_Fragmentation     450333
# VulnerabilityScan           372000
# DDoS-UDP_Fragmentation      285309
# DDoS-ACK_Fragmentation      283756
# MITM-ArpSpoofing            280920
# DNS_Spoofing                174211
# Recon-HostDiscovery         133532
# Recon-OSScan                 96503
# Recon-PortScan               80244
# DoS-HTTP_Flood               71489
# DDoS-HTTP_Flood              28790
# DDoS-SlowLoris               23426
# ...

# %%
df["label"].value_counts(normalize = True)
# Out:
# label
# DDoS-UDP_Flood             0.094125
# DDoS-ICMP_Flood            0.091191
# DDoS-SYN_Flood             0.084604
# DoS-UDP_Flood              0.081653
# DDoS-PSHACK_FLOOD          0.078595
# DDoS-TCP_Flood             0.074715
# DDoS-RSTFINFLOOD           0.060048
# DDoS-SynonymousIP_Flood    0.055991
# DoS-SYN_Flood              0.054635
# DoS-TCP_Flood              0.053658
# Benign_Final               0.050425
# Mirai-greeth_flood         0.043159
# Mirai-udpplain             0.036845
# Mirai-greip_flood          0.033391
# DDoS-ICMP_Fragmentation    0.020758
# VulnerabilityScan          0.017147
# DDoS-UDP_Fragmentation     0.013151
# DDoS-ACK_Fragmentation     0.013080
# MITM-ArpSpoofing           0.012949
# DNS_Spoofing               0.008030
# Recon-HostDiscovery        0.006155
# Recon-OSScan               0.004448
# Recon-PortScan             0.003699
# DoS-HTTP_Flood             0.003295
# DDoS-HTTP_Flood            0.001327
# DDoS-SlowLoris             0.001080
# ...
