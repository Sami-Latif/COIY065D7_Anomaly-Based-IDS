# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/sami/Documents/CS Postgrad/IDS/COIY065D7_Anomaly-Based-IDS/Data/entire_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46776700 entries, 0 to 46776699
# Data columns (total 40 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Header_Length    float64
#  1   Protocol Type    int64
#  2   Time_To_Live     float64
#  3   Rate             float64
#  4   fin_flag_number  float64
#  5   syn_flag_number  float64
#  6   rst_flag_number  float64
#  7   psh_flag_number  float64
#  8   ack_flag_number  float64
#  9   ece_flag_number  float64
#  10  cwr_flag_number  float64
#  11  ack_count        float64
#  12  syn_count        float64
#  13  fin_count        float64
#  14  rst_count        float64
#  15  HTTP             float64
#  16  HTTPS            float64
#  17  DNS              float64
#  18  Telnet           float64
#  19  SMTP             float64
#  20  SSH              float64
#  21  IRC              float64
#  22  TCP              float64
#  23  UDP              float64
#  24  DHCP             float64
#  25  ARP              float64
#  26  ICMP             float64
#  27  IGMP             float64
#  28  IPv              float64
#  29  LLC              float64
#  30  Tot sum          float64
#  31  Min              float64
#  32  Max              float64
#  33  AVG              float64
#  34  Std              float64
#  35  Tot size         float64
#  36  IAT              float64
#  37  Number           float64
#  38  Variance         float64
#  39  label            object
# dtypes: float64(38), int64(1), object(1)
# memory usage: 13.9+ GB

# %%
print(df.shape)
# Out:
# (46776700, 40)

# %%
df["label"].value_counts()
# Out:
# label
# DDoS-ICMP_Flood            7200501
# DDoS-UDP_Flood             5412231
# DDoS-TCP_Flood             4497649
# DDoS-PSHACK_FLOOD          4094772
# DDoS-SYN_Flood             4059179
# DDoS-RSTFINFLOOD           4045279
# DDoS-SynonymousIP_Flood    3598133
# DoS-UDP_Flood              3072993
# DoS-TCP_Flood              2671430
# DoS-SYN_Flood              2028836
# Benign_Final               1098191
# Mirai-greeth_flood          991834
# Mirai-udpplain              890574
# Mirai-greip_flood           751646
# DDoS-ICMP_Fragmentation     452490
# VulnerabilityScan           373351
# MITM-ArpSpoofing            307560
# DDoS-UDP_Fragmentation      286925
# DDoS-ACK_Fragmentation      285075
# DNS_Spoofing                178898
# Recon-HostDiscovery         134378
# Recon-OSScan                 98259
# Recon-PortScan               82284
# DoS-HTTP_Flood               71861
# DDoS-HTTP_Flood              28790
# DDoS-SlowLoris               23426
# DictionaryBruteForce         13064
# BrowserHijacking              5859
# CommandInjection              5409
# SqlInjection                  5245
# XSS                           3846
# Backdoor_Malware              3218
# Recon-PingSweep               2262
# Uploading_Attack              1252
# Name: count, dtype: int64

# %%
df["label"].value_counts(normalize = True)
# Out:
# label
# DDoS-ICMP_Flood            0.153933
# DDoS-UDP_Flood             0.115704
# DDoS-TCP_Flood             0.096151
# DDoS-PSHACK_FLOOD          0.087539
# DDoS-SYN_Flood             0.086778
# DDoS-RSTFINFLOOD           0.086481
# DDoS-SynonymousIP_Flood    0.076921
# DoS-UDP_Flood              0.065695
# DoS-TCP_Flood              0.057110
# DoS-SYN_Flood              0.043373
# Benign_Final               0.023477
# Mirai-greeth_flood         0.021204
# Mirai-udpplain             0.019039
# Mirai-greip_flood          0.016069
# DDoS-ICMP_Fragmentation    0.009673
# VulnerabilityScan          0.007982
# MITM-ArpSpoofing           0.006575
# DDoS-UDP_Fragmentation     0.006134
# DDoS-ACK_Fragmentation     0.006094
# DNS_Spoofing               0.003825
# Recon-HostDiscovery        0.002873
# Recon-OSScan               0.002101
# Recon-PortScan             0.001759
# DoS-HTTP_Flood             0.001536
# DDoS-HTTP_Flood            0.000615
# DDoS-SlowLoris             0.000501
# DictionaryBruteForce       0.000279
# BrowserHijacking           0.000125
# CommandInjection           0.000116
# SqlInjection               0.000112
# XSS                        0.000082
# Backdoor_Malware           0.000069
# Recon-PingSweep            0.000048
# Uploading_Attack           0.000027
# Name: proportion, dtype: float64
